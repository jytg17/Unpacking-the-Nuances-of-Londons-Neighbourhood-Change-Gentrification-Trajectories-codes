# %%
import pandas as pd

# %%
# read in relevant datasets

main_01 = pd.read_csv("main_01_cleaned_ml.csv")
main_11 = pd.read_csv("main_11_cleaned_ml.csv")

# %%
main_01.head()
# Out:
#   2011 census lower super output areas 2011 super output area - lower layer_x  \
# 0                            E01000001                    City of London 001A
# 1                            E01000002                    City of London 001B
# 2                            E01000003                    City of London 001C
# 3                            E01000005                    City of London 001E
# 4                            E01000006              Barking and Dagenham 016A
#
#    Local_authority_name  Pop_2001  Median_House_Prices_2001  \
# 0        City of London    1600.0                    245424
# 1        City of London    1470.0                    235000
# 2        City of London    1537.0                    190000
# 3        City of London    1073.0                    137500
# 4  Barking and Dagenham    1571.0                     60000
#
#    Median_income_2001  Age 0 to 4_pct  Age 5 to 7_pct  Age 8 to 9_pct  \
# ...

# %%
main_11.head()
# Out:
#   2011 census lower super output areas 2011 super output area - lower layer_x  \
# 0                            E01000001                    City of London 001A
# 1                            E01000002                    City of London 001B
# 2                            E01000003                    City of London 001C
# 3                            E01000005                    City of London 001E
# 4                            E01000006              Barking and Dagenham 016A
#
#    Local_authority_name  Pop_2011  Median_House_Prices_2011  \
# 0        City of London      1465                    497000
# 1        City of London      1436                    528750
# 2        City of London      1346                    335000
# 3        City of London       985                    300000
# 4  Barking and Dagenham      1703                    232500
#
#    Median_income_2011  Age 0 to 4_pct  Age 5 to 7_pct  Age 8 to 9_pct  \
# ...

# %% [markdown]
# ### Prep 2001 Datasets

# %%
# print feature column names

list(main_01.columns)
# Out:
# ['2011 census lower super output areas',
#  '2011 super output area - lower layer_x',
#  'Local_authority_name',
#  'Pop_2001',
#  'Median_House_Prices_2001',
#  'Median_income_2001',
#  'Age 0 to 4_pct',
#  'Age 5 to 7_pct',
#  'Age 8 to 9_pct',
#  'Age 10 to 14_pct',
#  'Age 15_pct',
#  'Age 16 to 17_pct',
#  'Age 18 to 19_pct',
#  'Age 20 to 24_pct',
#  'Age 25 to 29_pct',
#  'Age 30 to 44_pct',
#  'Age 45 to 59_pct',
#  'Age 60 to 64_pct',
#  'Age 65 to 74_pct',
#  'Age 75 to 84_pct',
#  'Age 85 to 89_pct',
#  'Age 90 and over_pct',
#  'One person household - Pensioner_pct',
#  'One person household - Other_pct',
#  'One family and no others - All pensioners_pct',
#  'One family and no others - married couple households - no children_pct',
#  'One family and no others - married couple households - with dependent children_pct',
#  'One family and no others - married couple households - all children non-dependent_pct',
# ...

# %%
# print feature column names

list(main_11.columns)
# Out:
# ['2011 census lower super output areas',
#  '2011 super output area - lower layer_x',
#  'Local_authority_name',
#  'Pop_2011',
#  'Median_House_Prices_2011',
#  'Median_income_2011',
#  'Age 0 to 4_pct',
#  'Age 5 to 7_pct',
#  'Age 8 to 9_pct',
#  'Age 10 to 14_pct',
#  'Age 15_pct',
#  'Age 16 to 17_pct',
#  'Age 18 to 19_pct',
#  'Age 20 to 24_pct',
#  'Age 25 to 29_pct',
#  'Age 30 to 44_pct',
#  'Age 45 to 59_pct',
#  'Age 60 to 64_pct',
#  'Age 65 to 74_pct',
#  'Age 75 to 84_pct',
#  'Age 85 to 89_pct',
#  'Age 90 and over_pct',
#  'One person household: Aged 65 and over_pct',
#  'One person household: Other_pct',
#  'One family only: All aged 65 and over_pct',
#  'One family only: Married or same-sex civil partnership couple: No children_pct',
#  'One family only: Married or same-sex civil partnership couple: Dependent children_pct',
#  'One family only: Married or same-sex civil partnership couple: All children non-dependent_pct',
# ...

# %%
# drop irrelevant features

df_modelling_01 = main_01.drop(columns=['2011 super output area - lower layer_x',
 'Local_authority_name'])

# %%
# re-arrange feature sequence

df_modelling_01 = df_modelling_01[[
 '2011 census lower super output areas',
 'Pop_2001',
 'avg_churn_01_10',
 'Age 0 to 4_pct',
 'Age 5 to 7_pct',
 'Age 8 to 9_pct',
 'Age 10 to 14_pct',
 'Age 15_pct',
 'Age 16 to 17_pct',
 'Age 18 to 19_pct',
 'Age 20 to 24_pct',
 'Age 25 to 29_pct',
 'Age 30 to 44_pct',
 'Age 45 to 59_pct',
 'Age 60 to 64_pct',
 'Age 65 to 74_pct',
 'Age 75 to 84_pct',
 'Age 85 to 89_pct',
 'Age 90 and over_pct',
 'One person household - Pensioner_pct',
 'One person household - Other_pct',
 'One family and no others - All pensioners_pct',
 'One family and no others - married couple households - no children_pct',
 'One family and no others - married couple households - with dependent children_pct',
 'One family and no others - married couple households - all children non-dependent_pct',
 'One family and no others - cohabiting couple households - no children_pct',
 'One family and no others - cohabiting couple households - with dependent children_pct',
 'One family and no others - cohabiting couple households - all children non-dependent_pct',
 'One family and no others - Lone parent households - with dependent children_pct',
 'One family and no others - Lone parent households - all children non-dependent_pct',
 'Other households - With dependent children_pct',
 'Other households - All students_pct',
 'Other households - All pensioner_pct',
 'Other households - Other_pct',
 'Average household size',
 'United Kingdom',
 'Republic of Ireland',
 'EU countries',
 'Rest of Europe',
 'Africa',
 'Asia',
 'North America',
 'South America',
 'Oceania',
 'White',
 'Mixed',
 'Asian/Asian British',
 'Black/Black British',
 'Christian',
 'Buddhist',
 'Hindu',
 'Jewish',
 'Muslim',
 'Sikh',
 'Other religion',
 'No religion',
 'Religion not stated',
 'No cars or vans in household',
 '1 car or van in household',
 '2 cars or vans in household',
 '3 cars or vans in household',
 '4 or more cars or vans in household',
 'Median_House_Prices_2001',
 'Median House Price-2010',
 'House_sales_pct',
 'Pop Density 2001',
 'dwellings_2001',
 'Occupancy rating of -1 or less_pct',
 'With central heating_pct',
 'Average number of rooms per household',
 'Owned outright_pct',
 'Owned with a mortgage or loan_pct',
 'Shared ownership_pct',
 'Rented from council(local authority)_pct',
 'Rented from a housing association/registered social landlord_pct',
 'Rented from a private landlord or letting agency_pct',
 'Other_pct',
 'All household spaces - with residents_pct',
 'Whole house or bungalow - detatched_pct',
 'Whole house or bungalow - semi-detatched_pct',
 'Whole house or bungalow - terraced_pct',
 'Flat, maisonette or apartment - in a purpose built block of flats or tenement_pct',
 'Flat, maisonette or apartment - part of a converted or shared house (includes bed-sit)_pct',
 'Flat, maisonette or apartment - in a commercial building_pct',
 'Median_income_2001',
 '1. Managers and senior officials_pct',
 '2. Professional occupations_pct',
 '3. Associate professional and technical occupations_pct',
 '4. Administrative and secretarial occupations_pct',
 '5. Skilled trades occupations_pct',
 '6. Personal service occupations_pct',
 '7. Sales and customer service occupations_pct',
 '8. Process, plant and machine operatives_pct',
 '9. Elementary occupations_pct',    
 'Economically active_pct',
 'X1_Higher_managerial_administrative_and_professional_occupations_2001_pct',
 'X2_Lower_managerial_administrative_and_professional_occupations_2001_pct',
 'X3_Intermediate_occupations_2001_pct',
 'X4_Small_employers_and_own_account_workers_2001_pct',
 'X5_Lower_supervisory_and_technical_occupations_2001_pct',
 'X6_Semi_routine_occupations_2001_pct',
 'X7_Routine_occupations_2001_pct',
 'X8_Never_worked_and_long_term_unemployed_2001_pct',
 'Not_classified_2001_pct',
 'Males - Part-time -Less than 15 hrs',
 'Males - Part-time - 16 to 30 hours',
 'Males - Full-time - 31 to 48 hours',
 'Males - Full-time - 49 or more hours',
 'Females - Part-time - Less than 15 hours',
 'Females - Part-time - 16 to 30 hours',
 'Females - Full-time - 31 to 48 hours',
 'Females - Full-time - 49 or more hours',
 'No qualifications',
 'Highest level of qualification: Level 1 qualifications',
 'Highest level of qualification: Level 2 qualifications',
 'Highest level of qualification: Level 3 qualifications',
 'Highest level of qualification: Level 4 qualifications and above',
 'Highest level of qualification: Other qualifications',
 'Work mainly at or from home',
 'Underground, metro, light rail, tram',
 'Train',
 'Bus, minibus or coach',
 'Motorcycle, scooter or moped',
 'Driving a car or van',
 'Passenger in a car or van',
 'Taxi or minicab',
 'Bicycle',
 'On foot',
 'Other'
]]

# %%
# rename features

df_modelling_01 = df_modelling_01.rename(columns = {
 '2011 census lower super output areas':'LSOA11CD',
 'Pop_2001':'Pop_size',
 'avg_churn_01_10': 'avg_pop_churn',
 'Age 0 to 4_pct':'age_0_4',
 'Age 5 to 7_pct':'age_5_7',
 'Age 8 to 9_pct':'age_8_9',
 'Age 10 to 14_pct':'age_10_14',
 'Age 15_pct':'age_15',
 'Age 16 to 17_pct':'age_16_17',
 'Age 18 to 19_pct':'age_18_19',
 'Age 20 to 24_pct':'age_20_24',
 'Age 25 to 29_pct':'age_25_29',
 'Age 30 to 44_pct':'age_30_44',
 'Age 45 to 59_pct':'age_45_59',
 'Age 60 to 64_pct':'age_60_64',
 'Age 65 to 74_pct':'age_65_74',
 'Age 75 to 84_pct':'age_75_84',
 'Age 85 to 89_pct':'age_85_89',
 'Age 90 and over_pct':'age_90_over',
 'One person household - Pensioner_pct':'1-personHse_aged',
 'One person household - Other_pct':'1-personHse_other',
 'One family and no others - All pensioners_pct':'1-family_aged',
 'One family and no others - married couple households - no children_pct':'1-family_married_noKids',
 'One family and no others - married couple households - with dependent children_pct':'1-family_married_depKids',
 'One family and no others - married couple households - all children non-dependent_pct':'1-family_married_noDepKids',
 'One family and no others - cohabiting couple households - no children_pct':'1-family_cohab_noKids',
 'One family and no others - cohabiting couple households - with dependent children_pct':'1-family_cohab_depKids',
 'One family and no others - cohabiting couple households - all children non-dependent_pct':'1-family_cohab_noDepKids',
 'One family and no others - Lone parent households - with dependent children_pct':'1-family_lone_depKids',
 'One family and no others - Lone parent households - all children non-dependent_pct':'1-family_lone_noDepKids',
 'Other households - With dependent children_pct':'otherHse_depKids',
 'Other households - All students_pct':'otherHse_students',
 'Other households - All pensioner_pct':'otherHse_aged',
 'Other households - Other_pct':'otherHse_other',
 'Average household size':'avg_hse_size',
 'United Kingdom':'born_UK',
 'Republic of Ireland':'born_IRE',
 'EU countries':'born_EU',
 'Rest of Europe':'born_restEUR',
 'Africa':'born_Africa',
 'Asia':'born_Asia',
 'North America':'born_NthAm',
 'South America':'born_SthAm',
 'Oceania':'born_Oceania',
 'White':'eth_white',
 'Mixed':'eth_mixed',
 'Asian/Asian British':'eth_asian',
 'Black/Black British':'eth_black',
 'Christian':'Christian',
 'Buddhist':'Buddhist',
 'Hindu':'Hindu',
 'Jewish':'Jewish',
 'Muslim':'Muslim',
 'Sikh':'Sikh',
 'Other religion':'Oth_religion',
 'No religion':'No_religion',
 'Religion not stated':'Religion_not_stated',
 'No cars or vans in household':'no_carsVans',
 '1 car or van in household':'1_carsVans',
 '2 cars or vans in household':'2_carsVans',
 '3 cars or vans in household':'3_carsVans',
 '4 or more cars or vans in household':'4_more_carsVans',
 'Median_House_Prices_2001':'Median_HsePrice_BaseYr',
 'Median House Price-2010':'Median_HsePrice_EndYr',
 'House_sales_pct':'avg_hse_sales',
 'Pop Density 2001': 'Pop_density',
 'dwellings_2001':'dwellings_no',
 'Occupancy rating of -1 or less_pct':'occup_rating',
 'With central heating_pct':'central_heating',
 'Average number of rooms per household':'avg_rooms',
 'Owned outright_pct':'tenure_owned_outright',
 'Owned with a mortgage or loan_pct':'tenure_owned_mortLoan',
 'Shared ownership_pct':'tenure_shared',
 'Rented from council(local authority)_pct':'tenure_rent_council',
 'Rented from a housing association/registered social landlord_pct':'tenure_rent_hsgAssc',
 'Rented from a private landlord or letting agency_pct':'tenure_rent_private',
 'Other_pct':'tenure_rent_other',
 'All household spaces - with residents_pct':'hsehold_usual_residents',
 'Whole house or bungalow - detatched_pct':'hse_detached',
 'Whole house or bungalow - semi-detatched_pct':'hse_semiDetached',
 'Whole house or bungalow - terraced_pct':'hse_terraced',
 'Flat, maisonette or apartment - in a purpose built block of flats or tenement_pct':'hse_flats',
 'Flat, maisonette or apartment - part of a converted or shared house (includes bed-sit)_pct':'hse_converted_shared',
 'Flat, maisonette or apartment - in a commercial building_pct':'hse_commercial',
 'Median_income_2001':'median_income',
 '1. Managers and senior officials_pct':'Managers_directors_senior_occup',
 '2. Professional occupations_pct':'Professional_occup',
 '3. Associate professional and technical occupations_pct':'Associate_professional_technical_occup',
 '4. Administrative and secretarial occupations_pct':'Administrative_secretarial_occup',
 '5. Skilled trades occupations_pct':'Skilled_trades_occup',
 '6. Personal service occupations_pct':'Caring_leisure_other_service_occup',
 '7. Sales and customer service occupations_pct':'Sales_customer_service_occup',
 '8. Process, plant and machine operatives_pct':'Process plant_machine_operatives_occup',
 '9. Elementary occupations_pct':'Elementary_occup',
 'Economically active_pct':'economically_active',
 'X1_Higher_managerial_administrative_and_professional_occupations_2001_pct':'NS-SEC_1',
 'X2_Lower_managerial_administrative_and_professional_occupations_2001_pct':'NS-SEC_2',
 'X3_Intermediate_occupations_2001_pct':'NS-SEC_3',
 'X4_Small_employers_and_own_account_workers_2001_pct':'NS-SEC_4',
 'X5_Lower_supervisory_and_technical_occupations_2001_pct':'NS-SEC_5',
 'X6_Semi_routine_occupations_2001_pct':'NS-SEC_6',
 'X7_Routine_occupations_2001_pct':'NS-SEC_7',
 'X8_Never_worked_and_long_term_unemployed_2001_pct':'NS-SEC_8',
 'Not_classified_2001_pct':'NS-SEC_noClass',
 'Males - Part-time -Less than 15 hrs':'Males_ptTime_less15hrs',
 'Males - Part-time - 16 to 30 hours':'Males_ptTime_16_30hrs',
 'Males - Full-time - 31 to 48 hours':'Males_FTime_31_48hrs',
 'Males - Full-time - 49 or more hours':'Males_FTime_more49hrs',
 'Females - Part-time - Less than 15 hours':'Females_ptTime_less15hrs',
 'Females - Part-time - 16 to 30 hours':'Females_ptTime_16_30hrs',
 'Females - Full-time - 31 to 48 hours':'Females_FTime_31_48hrs',
 'Females - Full-time - 49 or more hours':'Females_FTime_more49hrs',
 'No qualifications':'No_qual',
 'Highest level of qualification: Level 1 qualifications':'Lv1_qual',
 'Highest level of qualification: Level 2 qualifications':'Lv2_qual',
 'Highest level of qualification: Level 3 qualifications':'Lv3_qual',
 'Highest level of qualification: Level 4 qualifications and above':'Lv4_qual',
 'Highest level of qualification: Other qualifications':'Other_qual',
 'Work mainly at or from home':'toWork_home',
 'Underground, metro, light rail, tram':'toWork_underground_light_rail',
 'Train':'toWork_train',
 'Bus, minibus or coach':'toWork_bus',
 'Motorcycle, scooter or moped':'toWork_motorcycle',
 'Driving a car or van':'toWork_carVan',
 'Passenger in a car or van':'toWork_passenger_carVan',
 'Taxi or minicab':'toWork_taxi',
 'Bicycle':'toWork_bicycle',
 'On foot':'toWork_walk',
 'Other':'toWork_other'
})

# %%
# verify features

list(df_modelling_01.columns)
# Out:
# ['LSOA11CD',
#  'Pop_size',
#  'avg_pop_churn',
#  'age_0_4',
#  'age_5_7',
#  'age_8_9',
#  'age_10_14',
#  'age_15',
#  'age_16_17',
#  'age_18_19',
#  'age_20_24',
#  'age_25_29',
#  'age_30_44',
#  'age_45_59',
#  'age_60_64',
#  'age_65_74',
#  'age_75_84',
#  'age_85_89',
#  'age_90_over',
#  '1-personHse_aged',
#  '1-personHse_other',
#  '1-family_aged',
#  '1-family_married_noKids',
#  '1-family_married_depKids',
#  '1-family_married_noDepKids',
#  '1-family_cohab_noKids',
#  '1-family_cohab_depKids',
#  '1-family_cohab_noDepKids',
#  '1-family_lone_depKids',
#  '1-family_lone_noDepKids',
#  'otherHse_depKids',
#  'otherHse_students',
#  'otherHse_aged',
#  'otherHse_other',
#  'avg_hse_size',
#  'born_UK',
#  'born_IRE',
#  'born_EU',
#  'born_restEUR',
#  'born_Africa',
#  'born_Asia',
#  'born_NthAm',
#  'born_SthAm',
#  'born_Oceania',
#  'eth_white',
#  'eth_mixed',
#  'eth_asian',
#  'eth_black',
#  'Christian',
#  'Buddhist',
#  'Hindu',
#  'Jewish',
#  'Muslim',
# ...

# %%
df_modelling_01.head()
# Out:
#     LSOA11CD  Pop_size  avg_pop_churn  age_0_4  age_5_7  age_8_9  age_10_14  \
# 0  E01000001    1600.0       2.275180     2.44     0.75     0.62       1.94
# 1  E01000002    1470.0       2.284483     3.27     1.16     1.29       2.38
# 2  E01000003    1537.0       2.934233     4.03     1.89     1.30       1.11
# 3  E01000005    1073.0       2.599725     7.18     3.73     2.89       6.80
# 4  E01000006    1571.0       2.146893     7.32     2.93     2.80       6.24
#
#    age_15  age_16_17  age_18_19  ...  toWork_underground_light_rail  \
# 0    0.19       0.88       1.06  ...                      23.084201
# 1    0.20       0.41       0.54  ...                      21.212121
# 2    0.33       1.63       2.41  ...                      23.247232
# 3    1.49       2.61       1.77  ...                      28.826531
# 4    1.46       2.55       2.99  ...                      27.647868
#
#    toWork_train  toWork_bus  toWork_motorcycle  toWork_carVan  \
# ...

# %%
# checkpoint - output file
# df_modelling_01.to_csv('df_modelling_01.csv')

# %% [markdown]
# ### Prep 2011 Datasets

# %%
# drop irrelevant features

df_modelling_11 = main_11.drop(columns=['2011 super output area - lower layer_x',
 'Local_authority_name'])

# %%
# re-arrange feature sequence

df_modelling_11 = df_modelling_11[[
 '2011 census lower super output areas',
 'Pop_2011',
 'avg_churn_11_16',
 'Age 0 to 4_pct',
 'Age 5 to 7_pct',
 'Age 8 to 9_pct',
 'Age 10 to 14_pct',
 'Age 15_pct',
 'Age 16 to 17_pct',
 'Age 18 to 19_pct',
 'Age 20 to 24_pct',
 'Age 25 to 29_pct',
 'Age 30 to 44_pct',
 'Age 45 to 59_pct',
 'Age 60 to 64_pct',
 'Age 65 to 74_pct',
 'Age 75 to 84_pct',
 'Age 85 to 89_pct',
 'Age 90 and over_pct', 
 'One person household: Aged 65 and over_pct',
 'One person household: Other_pct',
 'One family only: All aged 65 and over_pct',
 'One family only: Married or same-sex civil partnership couple: No children_pct',
 'One family only: Married or same-sex civil partnership couple: Dependent children_pct',
 'One family only: Married or same-sex civil partnership couple: All children non-dependent_pct',
 'One family only: Cohabiting couple: No children_pct',
 'One family only: Cohabiting couple: Dependent children_pct',
 'One family only: Cohabiting couple: All children non-dependent_pct',
 'One family only: Lone parent: Dependent children_pct',
 'One family only: Lone parent: All children non-dependent_pct',
 'Other household types: With dependent children_pct',
 'Other household types: All full-time students_pct',
 'Other household types: All aged 65 and over_pct',
 'Other household types: Other_pct',
 'Average household size',  
 'Europe: United Kingdom: Total',
 'Europe: Ireland',
 'Europe: Other Europe: EU Countries: Total',
 'Europe: Other Europe: Rest of Europe: Total',
 'Africa: Total',
 'Middle East and Asia: Total',
 'The Americas and the Caribbean: North America and The Caribbeans: Total',
 'The Americas and the Caribbean: South America',
 'Antarctica and Oceania: Total',
 'White_pct',
 'Mixed/multiple ethnic groups_pct',
 'Asian/Asian British_pct',
 'Black/African/Caribbean/Black British_pct',    
 'Christian_pct',
 'Buddhist_pct',
 'Hindu_pct',
 'Jewish_pct',
 'Muslim_pct',
 'Sikh_pct',
 'Other religion_pct',
 'No religion_pct',
 'Religion not stated_pct',
 'No cars or vans in household_pct',
 '1 car or van in household_pct',
 '2 cars or vans in household_pct',
 '3 cars or vans in household_pct',
 '4 or more cars or vans in household_pct',    
 'Median_House_Prices_2011',
 'Median House Price 2016',
 'House_sales_pct',   
 'Density (number of persons per hectare)',
 'dwellings_2011', 
 'Occupancy rating (rooms) of -1 or less_pct',
 'Does have central heating_pct',    
 'Average number of rooms per household',
 'Owned: Owned outright_pct',
 'Owned: Owned with a mortgage or loan_pct',
 'Shared ownership (part owned and part rented)_pct',
 'Social rented: Rented from council (Local Authority)_pct',
 'Social rented: Other_pct',
 'Private rented: Private landlord or letting agency_pct',
 'Private rented: Other_pct',
 'Household spaces with at least one usual resident_pct',
 'Whole house or bungalow: Detached_pct',
 'Whole house or bungalow: Semi-detached_pct',
 'Whole house or bungalow: Terraced (including end-terrace)_pct',
 'Flat, maisonette or apartment: Purpose-built block of flats or tenement_pct',
 'Flat, maisonette or apartment: Part of a converted or shared house (including bed-sits)_pct',
 'Flat, maisonette or apartment: In a commercial building_pct',
 'Median_income_2011',
 '1. Managers, directors and senior officials_pct',
 '2. Professional occupations_pct',
 '3. Associate professional and technical occupations_pct',
 '4. Administrative and secretarial occupations_pct',
 '5. Skilled trades occupations_pct',
 '6. Caring, leisure and other service occupations_pct',
 '7. Sales and customer service occupations_pct',
 '8. Process plant and machine operatives_pct',
 '9. Elementary occupations_pct',
 'Economically active_pct',
 'X1_Higher_managerial_administrative_and_professional_occupations_2011_pct',
 'X2_Lower_managerial_administrative_and_professional_occupations_2011_pct',
 'X3_Intermediate_occupations_2011_pct',
 'X4_Small_employers_and_own_account_workers_2011_pct',
 'X5_Lower_supervisory_and_technical_occupations_2011_pct',
 'X6_Semi_routine_occupations_2011_pct',
 'X7_Routine_occupations_2011_pct',
 'X8_Never_worked_and_long_term_unemployed_2011_pct',
 'Not_classified_2011_pct',
 'Males: Part-time: 15 hours or less worked',
 'Males: Part-time: 16 to 30 hours worked',
 'Males: Full-time: 31 to 48 hours worked',
 'Males: Full-time: 49 or more hours worked',
 'Females: Part-time: 15 hours or less worked',
 'Females: Part-time: 16 to 30 hours worked',
 'Females: Full-time: 31 to 48 hours worked',
 'Females: Full-time: 49 or more hours worked',
 'No qualifications',
 'Highest level of qualification: Level 1 qualifications',
 'Highest level of qualification: Level 2 qualifications',
 'Highest level of qualification: Level 3 qualifications',
 'Highest level of qualification: Level 4 qualifications and above',
 'Highest level of qualification: Other qualifications',
 'Work mainly at or from home_pct',
 'Underground, metro, light rail, tram_pct',
 'Train_pct',
 'Bus, minibus or coach_pct',
 'Motorcycle, scooter or moped_pct',
 'Driving a car or van_pct',
 'Passenger in a car or van_pct',
 'Taxi_pct',
 'Bicycle_pct',
 'On foot_pct',
 'Other method of travel to work_pct'
]]

# %%
# rename features to be consistent with 2001 modelling dataset

df_modelling_11 = df_modelling_11.rename(columns={
 '2011 census lower super output areas':'LSOA11CD',
 'Pop_2011':'Pop_size',
 'avg_churn_11_16': 'avg_pop_churn',
 'Age 0 to 4_pct':'age_0_4',
 'Age 5 to 7_pct':'age_5_7',
 'Age 8 to 9_pct':'age_8_9',
 'Age 10 to 14_pct':'age_10_14',
 'Age 15_pct':'age_15',
 'Age 16 to 17_pct':'age_16_17',
 'Age 18 to 19_pct':'age_18_19',
 'Age 20 to 24_pct':'age_20_24',
 'Age 25 to 29_pct':'age_25_29',
 'Age 30 to 44_pct':'age_30_44',
 'Age 45 to 59_pct':'age_45_59',
 'Age 60 to 64_pct':'age_60_64',
 'Age 65 to 74_pct':'age_65_74',
 'Age 75 to 84_pct':'age_75_84',
 'Age 85 to 89_pct':'age_85_89',
 'Age 90 and over_pct':'age_90_over',
 'One person household: Aged 65 and over_pct':'1-personHse_aged',
 'One person household: Other_pct':'1-personHse_other',
 'One family only: All aged 65 and over_pct':'1-family_aged',
 'One family only: Married or same-sex civil partnership couple: No children_pct':'1-family_married_noKids',
 'One family only: Married or same-sex civil partnership couple: Dependent children_pct':'1-family_married_depKids',
 'One family only: Married or same-sex civil partnership couple: All children non-dependent_pct':'1-family_married_noDepKids',
 'One family only: Cohabiting couple: No children_pct':'1-family_cohab_noKids',
 'One family only: Cohabiting couple: Dependent children_pct':'1-family_cohab_depKids',
 'One family only: Cohabiting couple: All children non-dependent_pct':'1-family_cohab_noDepKids',
 'One family only: Lone parent: Dependent children_pct':'1-family_lone_depKids',
 'One family only: Lone parent: All children non-dependent_pct':'1-family_lone_noDepKids',
 'Other household types: With dependent children_pct':'otherHse_depKids',
 'Other household types: All full-time students_pct':'otherHse_students',
 'Other household types: All aged 65 and over_pct':'otherHse_aged',
 'Other household types: Other_pct':'otherHse_other',
 'Average household size':'avg_hse_size',
 'Europe: United Kingdom: Total':'born_UK',
 'Europe: Ireland':'born_IRE',
 'Europe: Other Europe: EU Countries: Total':'born_EU',
 'Europe: Other Europe: Rest of Europe: Total':'born_restEUR',
 'Africa: Total':'born_Africa',
 'Middle East and Asia: Total':'born_Asia',
 'The Americas and the Caribbean: North America and The Caribbeans: Total':'born_NthAm',
 'The Americas and the Caribbean: South America':'born_SthAm',
 'Antarctica and Oceania: Total':'born_Oceania',
 'White_pct':'eth_white',
 'Mixed/multiple ethnic groups_pct':'eth_mixed',
 'Asian/Asian British_pct':'eth_asian',
 'Black/African/Caribbean/Black British_pct':'eth_black',    
 'Christian_pct':'Christian',
 'Buddhist_pct':'Buddhist',
 'Hindu_pct':'Hindu',
 'Jewish_pct':'Jewish',
 'Muslim_pct':'Muslim',
 'Sikh_pct':'Sikh',
 'Other religion_pct':'Oth_religion',
 'No religion_pct':'No_religion',
 'Religion not stated_pct':'Religion_not_stated',
 'No cars or vans in household_pct':'no_carsVans',
 '1 car or van in household_pct':'1_carsVans',
 '2 cars or vans in household_pct':'2_carsVans',
 '3 cars or vans in household_pct':'3_carsVans',
 '4 or more cars or vans in household_pct':'4_more_carsVans',    
 'Median_House_Prices_2011':'Median_HsePrice_BaseYr',
 'Median House Price 2016':'Median_HsePrice_EndYr',
 'House_sales_pct':'avg_hse_sales',
 'Density (number of persons per hectare)': 'Pop_density',
 'dwellings_2011':'dwellings_no', 
 'Occupancy rating (rooms) of -1 or less_pct':'occup_rating',
 'Does have central heating_pct':'central_heating',    
 'Average number of rooms per household':'avg_rooms',
 'Owned: Owned outright_pct':'tenure_owned_outright',
 'Owned: Owned with a mortgage or loan_pct':'tenure_owned_mortLoan',
 'Shared ownership (part owned and part rented)_pct':'tenure_shared',
 'Social rented: Rented from council (Local Authority)_pct':'tenure_rent_council',
 'Social rented: Other_pct':'tenure_rent_hsgAssc',
 'Private rented: Private landlord or letting agency_pct':'tenure_rent_private',
 'Private rented: Other_pct':'tenure_rent_other',
 'Household spaces with at least one usual resident_pct':'hsehold_usual_residents',
 'Whole house or bungalow: Detached_pct':'hse_detached',
 'Whole house or bungalow: Semi-detached_pct':'hse_semiDetached',
 'Whole house or bungalow: Terraced (including end-terrace)_pct':'hse_terraced',
 'Flat, maisonette or apartment: Purpose-built block of flats or tenement_pct':'hse_flats',
 'Flat, maisonette or apartment: Part of a converted or shared house (including bed-sits)_pct':'hse_converted_shared',
 'Flat, maisonette or apartment: In a commercial building_pct':'hse_commercial',
 'Median_income_2011':'median_income',
 '1. Managers, directors and senior officials_pct':'Managers_directors_senior_occup',
 '2. Professional occupations_pct':'Professional_occup',
 '3. Associate professional and technical occupations_pct':'Associate_professional_technical_occup',
 '4. Administrative and secretarial occupations_pct':'Administrative_secretarial_occup',
 '5. Skilled trades occupations_pct':'Skilled_trades_occup',
 '6. Caring, leisure and other service occupations_pct':'Caring_leisure_other_service_occup',
 '7. Sales and customer service occupations_pct':'Sales_customer_service_occup',
 '8. Process plant and machine operatives_pct':'Process plant_machine_operatives_occup',
 '9. Elementary occupations_pct':'Elementary_occup',
 'Economically active_pct':'economically_active',
 'X1_Higher_managerial_administrative_and_professional_occupations_2011_pct':'NS-SEC_1',
 'X2_Lower_managerial_administrative_and_professional_occupations_2011_pct':'NS-SEC_2',
 'X3_Intermediate_occupations_2011_pct':'NS-SEC_3',
 'X4_Small_employers_and_own_account_workers_2011_pct':'NS-SEC_4',
 'X5_Lower_supervisory_and_technical_occupations_2011_pct':'NS-SEC_5',
 'X6_Semi_routine_occupations_2011_pct':'NS-SEC_6',
 'X7_Routine_occupations_2011_pct':'NS-SEC_7',
 'X8_Never_worked_and_long_term_unemployed_2011_pct':'NS-SEC_8',
 'Not_classified_2011_pct':'NS-SEC_noClass',
 'Males: Part-time: 15 hours or less worked':'Males_ptTime_less15hrs',
 'Males: Part-time: 16 to 30 hours worked':'Males_ptTime_16_30hrs',
 'Males: Full-time: 31 to 48 hours worked':'Males_FTime_31_48hrs',
 'Males: Full-time: 49 or more hours worked':'Males_FTime_more49hrs',
 'Females: Part-time: 15 hours or less worked':'Females_ptTime_less15hrs',
 'Females: Part-time: 16 to 30 hours worked':'Females_ptTime_16_30hrs',
 'Females: Full-time: 31 to 48 hours worked':'Females_FTime_31_48hrs',
 'Females: Full-time: 49 or more hours worked':'Females_FTime_more49hrs',
 'No qualifications':'No_qual',
 'Highest level of qualification: Level 1 qualifications':'Lv1_qual',
 'Highest level of qualification: Level 2 qualifications':'Lv2_qual',
 'Highest level of qualification: Level 3 qualifications':'Lv3_qual',
 'Highest level of qualification: Level 4 qualifications and above':'Lv4_qual',
 'Highest level of qualification: Other qualifications':'Other_qual',
 'Work mainly at or from home_pct':'toWork_home',
 'Underground, metro, light rail, tram_pct':'toWork_underground_light_rail',
 'Train_pct':'toWork_train',
 'Bus, minibus or coach_pct':'toWork_bus',
 'Motorcycle, scooter or moped_pct':'toWork_motorcycle',
 'Driving a car or van_pct':'toWork_carVan',
 'Passenger in a car or van_pct':'toWork_passenger_carVan',
 'Taxi_pct':'toWork_taxi',
 'Bicycle_pct':'toWork_bicycle',
 'On foot_pct':'toWork_walk',
 'Other method of travel to work_pct':'toWork_other'
})

# %%
df_modelling_11.head()
# Out:
#     LSOA11CD  Pop_size  avg_pop_churn  age_0_4  age_5_7  age_8_9  age_10_14  \
# 0  E01000001      1465       5.980216     3.41     1.30     0.96       1.77
# 1  E01000002      1436       6.106322     4.18     2.30     0.91       2.09
# 2  E01000003      1346       5.059022     3.94     1.04     0.59       1.78
# 3  E01000005       985       5.937643     4.26     3.86     2.23       4.97
# 4  E01000006      1703       5.273070     9.04     4.46     2.70       5.87
#
#    age_15  age_16_17  age_18_19  ...  toWork_underground_light_rail  \
# 0    0.41       0.48       0.41  ...                      14.660115
# 1    0.49       0.77       0.70  ...                      15.468227
# 2    0.37       2.45       2.53  ...                      13.520871
# 3    1.32       1.83       1.73  ...                      13.842173
# 4    1.06       2.00       1.82  ...                      20.463629
#
#    toWork_train  toWork_bus  toWork_motorcycle  toWork_carVan  \
# ...

# %%
# checkpoint - output file
# df_modelling_11.to_csv("df_modelling_11.csv")

# %%
# checking for null columns

list(df_modelling_01.isna().any())
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %%
# checking for null columns

list(df_modelling_11.isna().any())
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
# ...

# %% [markdown]
# ### Scaling the variables

# %%
# checkpoint - reload the files

#df_modelling_01 = pd.read_csv("df_modelling_01.csv").drop(columns="Unnamed: 0")
# df_modelling_11 = pd.read_csv("df_modelling_11.csv").drop(columns="Unnamed: 0")

# %%
from sklearn.preprocessing import RobustScaler

# %%
df_modelling_01 = df_modelling_01.set_index("LSOA11CD")
df_modelling_11 = df_modelling_11.set_index("LSOA11CD")

# %%
# re-scale 2001 variables

scaler_01 = RobustScaler()
df_modelling_std_01 = scaler_01.fit_transform(df_modelling_01)
df_modelling_std_01 = pd.DataFrame(df_modelling_std_01, index = df_modelling_01.index, columns=df_modelling_01.columns)

# %%
df_modelling_std_01.head()
# Out:
#            Pop_size  avg_pop_churn   age_0_4   age_5_7   age_8_9  age_10_14  \
# LSOA11CD
# E01000001  0.854701       0.037677 -1.731343 -1.986667 -1.702703  -1.606870
# E01000002 -0.256410       0.056527 -1.377399 -1.713333 -1.099099  -1.438931
# E01000003  0.316239       1.373138 -1.053305 -1.226667 -1.090090  -1.923664
# E01000005 -3.649573       0.695312  0.289979  0.000000  0.342342   0.248092
# E01000006  0.606838      -0.222276  0.349680 -0.533333  0.261261   0.034351
#
#              age_15  age_16_17  age_18_19  age_20_24  ...  \
# LSOA11CD                                              ...
# E01000001 -1.454545  -1.309735  -1.136842  -0.257426  ...
# E01000002 -1.439394  -1.725664  -1.684211  -0.660066  ...
# E01000003 -1.242424  -0.646018   0.284211   0.085809  ...
# E01000005  0.515152   0.221239  -0.389474   0.059406  ...
# E01000006  0.469697   0.168142   0.894737   0.075908  ...
#
#            toWork_underground_light_rail  toWork_train  toWork_bus  \
# LSOA11CD
# ...

# %%
# checkpoint - output file
# df_modelling_std_01.to_csv("df_modelling_std_01.csv")

# %%
# re-scale 2011 variables

scaler_11 = RobustScaler()
df_modelling_std_11 = scaler_11.fit_transform(df_modelling_11)
df_modelling_std_11 = pd.DataFrame(df_modelling_std_11, index = df_modelling_11.index, columns=df_modelling_11.columns)

# %%
df_modelling_std_11.head()
# Out:
#            Pop_size  avg_pop_churn   age_0_4   age_5_7   age_8_9  age_10_14  \
# LSOA11CD
# E01000001 -0.658537       0.517292 -1.383142 -1.615385 -1.265306     -1.564
# E01000002 -0.759582       0.617433 -1.088123 -0.916084 -1.316327     -1.436
# E01000003 -1.073171      -0.214230 -1.180077 -1.797203 -1.642857     -1.560
# E01000005 -2.331010       0.483485 -1.057471  0.174825  0.030612     -0.284
# E01000006  0.170732      -0.044254  0.773946  0.594406  0.510204      0.076
#
#              age_15  age_16_17  age_18_19  age_20_24  ...  \
# LSOA11CD                                              ...
# E01000001 -1.107692  -1.504132  -1.732673  -0.899489  ...
# E01000002 -0.984615  -1.264463  -1.445545  -1.413969  ...
# E01000003 -1.169231   0.123967   0.366337  -0.415673  ...
# E01000005  0.292308  -0.388430  -0.425743   0.991482  ...
# E01000006 -0.107692  -0.247934  -0.336634   0.214651  ...
#
#            toWork_underground_light_rail  toWork_train  toWork_bus  \
# LSOA11CD
# ...

# %%
# checkpoint - output file
# df_modelling_std_11.to_csv("df_modelling_std_11.csv")

# %% [markdown]
# ### Attach Clustering Labels to 2001 Modelling Dataset

# %%
labels = pd.read_csv("LSOA_labels_forMapping.csv").drop(columns="Unnamed: 0")

# %%
labels.head()
# Out:
#    LSOA_Code Class_1_status Class_2_status Class_3_status
# 0  E01000001            STB            STB            STB
# 1  E01000002            STB            STB            STB
# 2  E01000003            STB            STB            STB
# 3  E01000005            STB            STB            STB
# 4  E01000006            ASC            IUP            IUP

# %%
df_modelling_std_01 = df_modelling_std_01.reset_index()

# %%
# merge the inputs for modelling and cluster labels

df_modelling_std_01_labels = df_modelling_std_01.merge(labels[["LSOA_Code","Class_2_status", "Class_3_status"]], left_on="LSOA11CD", right_on="LSOA_Code", how = "left")

# %%
df_modelling_std_01_labels = df_modelling_std_01_labels.drop(columns="LSOA_Code")

# %%
df_modelling_std_01_labels.head()
# Out:
#     LSOA11CD  Pop_size  avg_pop_churn   age_0_4   age_5_7   age_8_9  \
# 0  E01000001  0.854701       0.037677 -1.731343 -1.986667 -1.702703
# 1  E01000002 -0.256410       0.056527 -1.377399 -1.713333 -1.099099
# 2  E01000003  0.316239       1.373138 -1.053305 -1.226667 -1.090090
# 3  E01000005 -3.649573       0.695312  0.289979  0.000000  0.342342
# 4  E01000006  0.606838      -0.222276  0.349680 -0.533333  0.261261
#
#    age_10_14    age_15  age_16_17  age_18_19  ...  toWork_bus  \
# 0  -1.606870 -1.454545  -1.309735  -1.136842  ...   -0.893246
# 1  -1.438931 -1.439394  -1.725664  -1.684211  ...   -0.660327
# 2  -1.923664 -1.242424  -0.646018   0.284211  ...   -0.515927
# 3   0.248092  0.515152   0.221239  -0.389474  ...    0.159427
# 4   0.034351  0.469697   0.168142   0.894737  ...   -0.187429
#
#    toWork_motorcycle  toWork_carVan  toWork_passenger_carVan  toWork_taxi  \
# 0          -0.378079      -1.108180                -0.915629     3.578703
# ...

# %%
# transpose labels

df_modelling_std_01_labels["GEN_Class2"]="NON-GEN"
df_modelling_std_01_labels["GEN_Class3"]="NON-GEN"

# %%
for i in range(len(df_modelling_std_01_labels)):
    if df_modelling_std_01_labels.loc[i,"Class_2_status"] == "GEN":
        df_modelling_std_01_labels.loc[i,"GEN_Class2"] = "GEN"
    if df_modelling_std_01_labels.loc[i,"Class_3_status"] == "MargGen":
        df_modelling_std_01_labels.loc[i,"GEN_Class3"] = "MargGen"
    if df_modelling_std_01_labels.loc[i,"Class_3_status"] == "MainGen":
        df_modelling_std_01_labels.loc[i,"GEN_Class3"] = "MainGen"
    if df_modelling_std_01_labels.loc[i,"Class_3_status"] == "SupGen":
        df_modelling_std_01_labels.loc[i,"GEN_Class3"] = "SupGen"
    else:
        continue

# %%
df_modelling_std_01_labels.head()
# Out:
#     LSOA11CD  Pop_size  avg_pop_churn   age_0_4   age_5_7   age_8_9  \
# 0  E01000001  0.854701       0.037677 -1.731343 -1.986667 -1.702703
# 1  E01000002 -0.256410       0.056527 -1.377399 -1.713333 -1.099099
# 2  E01000003  0.316239       1.373138 -1.053305 -1.226667 -1.090090
# 3  E01000005 -3.649573       0.695312  0.289979  0.000000  0.342342
# 4  E01000006  0.606838      -0.222276  0.349680 -0.533333  0.261261
#
#    age_10_14    age_15  age_16_17  age_18_19  ...  toWork_carVan  \
# 0  -1.606870 -1.454545  -1.309735  -1.136842  ...      -1.108180
# 1  -1.438931 -1.439394  -1.725664  -1.684211  ...      -1.089724
# 2  -1.923664 -1.242424  -0.646018   0.284211  ...      -1.214237
# 3   0.248092  0.515152   0.221239  -0.389474  ...      -1.131680
# 4   0.034351  0.469697   0.168142   0.894737  ...      -0.176290
#
#    toWork_passenger_carVan  toWork_taxi  toWork_bicycle  toWork_walk  \
# 0                -0.915629     3.578703       -0.142289     8.831109
# ...

# %%
# checkpoint - output file
# df_modelling_std_01_labels.to_csv("df_modelling_std_01_labels.csv")
