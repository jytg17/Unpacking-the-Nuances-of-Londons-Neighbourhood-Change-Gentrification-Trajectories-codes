# %%
# import pandas library

import pandas as pd

# %%
# read in relevant files

df_score = pd.read_csv("score_analysis_new.csv")
df_score = df_score.drop(columns = "Unnamed: 0")

# %%
df_score.head()
# Out:
#    LSOA_Code               LSOA_Name    LADcode  Local_authority_name  \
# 0  E01000001        CityofLondon001A  E09000001        City of London
# 1  E01000002        CityofLondon001B  E09000001        City of London
# 2  E01000003        CityofLondon001C  E09000001        City of London
# 3  E01000005        CityofLondon001E  E09000001        City of London
# 4  E01000006  BarkingandDagenham016A  E09000002  Barking and Dagenham
#
#    pop_2001  pop_2011  Median_House_Prices_2001  Median_House_Prices_2011  \
# 0      1600      1465                    245424                    497000
# 1      1470      1436                    235000                    528750
# 2      1537      1346                    190000                    335000
# 3      1073       985                    137500                    300000
# 4      1571      1703                     60000                    232500
#
#    All_cat_qual_2001  Level_4_qualifications_and_above_2001  ...  \
# 0               1423                                   1029  ...
# 1               1261                                    862  ...
# 2               1230                                    619  ...
# 3                763                                    239  ...
# 4               1160                                    261  ...
#
#    Median_income_2001  Median_income_2011  Score_2001  Score_2011  Rank_2001  \
# 0               45630               65520    2.192576    4.439991       65.0
# 1               44970               66300    1.993602    4.647998       89.0
# 2               36330               54140    0.517826    2.163691      613.0
# 3               31530               46740   -0.648125    0.806908     1843.0
# 4               26360               38200   -1.529709    0.006023     3841.0
#
#    Rank_2011  Rank_chg   Z_score  score_chg  status
# 0      147.0     -82.0 -0.182004   2.247415     STB
# 1      128.0     -39.0 -0.086563   2.654396     STB
# 2      712.0     -99.0 -0.219737   1.645864     STB
# 3     1730.0     113.0  0.250811   1.455033     STB
# 4     2827.0    1014.0  2.250639   1.535732     ASC
#
# [5 rows x 30 columns]

# %%
# verify the breakdown of neighbourhood states

df_score.groupby("status").size()
# Out:
# status
# ASC     732
# DEC     619
# STB    3484
# dtype: int64

# %%
# extract only ascending LSOAs

ascending_LSOA = df_score[df_score["status"] == "ASC"]

# %%
# check extracted dataframe

ascending_LSOA
# Out:
#       LSOA_Code               LSOA_Name    LADcode  Local_authority_name  \
# 4     E01000006  BarkingandDagenham016A  E09000002  Barking and Dagenham
# 8     E01000010  BarkingandDagenham015C  E09000002  Barking and Dagenham
# 26    E01000029  BarkingandDagenham001C  E09000002  Barking and Dagenham
# 29    E01000032  BarkingandDagenham002B  E09000002  Barking and Dagenham
# 40    E01000043  BarkingandDagenham019B  E09000002  Barking and Dagenham
# 65    E01000069  BarkingandDagenham011C  E09000002  Barking and Dagenham
# 88    E01000092  BarkingandDagenham019E  E09000002  Barking and Dagenham
# 113   E01000117              Barnet010A  E09000003                Barnet
# 126   E01000130              Barnet021A  E09000003                Barnet
# 132   E01000136              Barnet038B  E09000003                Barnet
# 133   E01000137              Barnet041A  E09000003                Barnet
# 135   E01000139              Barnet041B  E09000003                Barnet
# 139   E01000143              Barnet041D  E09000003                Barnet
# 142   E01000146              Barnet038D  E09000003                Barnet
# 154   E01000159              Barnet015B  E09000003                Barnet
# 159   E01000164              Barnet022D  E09000003                Barnet
# 164   E01000169              Barnet003C  E09000003                Barnet
# 171   E01000176              Barnet027A  E09000003                Barnet
# 176   E01000181              Barnet029D  E09000003                Barnet
# 186   E01000191              Barnet014F  E09000003                Barnet
# 194   E01000199              Barnet025B  E09000003                Barnet
# 196   E01000201              Barnet028C  E09000003                Barnet
# 202   E01000207              Barnet033C  E09000003                Barnet
# 207   E01000212              Barnet035D  E09000003                Barnet
# 208   E01000213              Barnet033F  E09000003                Barnet
# 212   E01000217              Barnet035F  E09000003                Barnet
# 223   E01000228              Barnet007A  E09000003                Barnet
# 244   E01000249              Barnet001B  E09000003                Barnet
# 262   E01000267              Barnet005A  E09000003                Barnet
# 264   E01000269              Barnet005C  E09000003                Barnet
# ...         ...                     ...        ...                   ...
# 4762  E01033575              Newham034G  E09000025                Newham
# 4763  E01033576              Newham034H  E09000025                Newham
# 4765  E01033578              Newham013E  E09000025                Newham
# 4766  E01033579              Newham013F  E09000025                Newham
# 4769  E01033582              Newham037H  E09000025                Newham
# 4770  E01033583              Newham013G  E09000025                Newham
# 4772  E01033585              Newham034J  E09000025                Newham
# 4773  E01033586              Newham013H  E09000025                Newham
# 4776  E01033589           Redbridge030H  E09000026             Redbridge
# 4782  E01033595         Westminster013E  E09000033           Westminster
# 4783  E01033596         Westminster013F  E09000033           Westminster
# 4784  E01033597         Westminster023F  E09000033           Westminster
# 4786  E01033599         Westminster023G  E09000033           Westminster
# 4787  E01033600         Westminster007F  E09000033           Westminster
# 4790  E01033603         Westminster009I  E09000033           Westminster
# 4797  E01033699             Hackney021G  E09000012               Hackney
# 4798  E01033700             Hackney021H  E09000012               Hackney
# 4802  E01033704             Hackney023F  E09000012               Hackney
# 4803  E01033705             Hackney028D  E09000012               Hackney
# 4805  E01033707             Hackney021I  E09000012               Hackney
# 4814  E01033726           Greenwich034E  E09000011             Greenwich
# 4818  E01033730           Greenwich035D  E09000011             Greenwich
# 4819  E01033731           Greenwich004E  E09000011             Greenwich
# 4820  E01033732           Greenwich036D  E09000011             Greenwich
# 4821  E01033733           Greenwich036E  E09000011             Greenwich
# 4822  E01033734           Greenwich004F  E09000011             Greenwich
# 4823  E01033735           Greenwich004G  E09000011             Greenwich
# 4824  E01033736           Greenwich004H  E09000011             Greenwich
# 4830  E01033742           Greenwich007F  E09000011             Greenwich
# 4834  E01033746           Greenwich038E  E09000011             Greenwich
#
#       pop_2001  pop_2011  Median_House_Prices_2001  Median_House_Prices_2011  \
# 4         1571      1703                     60000                    232500
# 8         1442      2840                     90000                    143000
# 26        1624      1602                    107500                    244500
# 29        1561      1629                    100500                    234000
# 40        1245      1358                     85995                    217500
# 65        1412      1763                    135498                    286250
# 88        1432      2674                     84500                    180000
# 113       1536      1819                    175000                    335000
# 126       1540      1603                     66978                    233000
# 132       1442      1532                    287475                   2825000
# 133       1511      1729                    115000                    312000
# 135       1350      1429                    182500                    900000
# 139       1359      1459                    135000                   1450000
# 142       1472      1716                    309750                    834938
# 154       1491      1777                    133000                    427750
# 159       1500      1686                     95000                    292250
# 164       1493      1490                    106000                    307750
# 171       1519      1613                     95000                    382500
# 176       1519      1711                    177500                    732500
# 186       1370      1525                    184000                    495000
# 194       1491      1617                    196250                    765000
# 196       1462      1531                    295000                   1042500
# 202       1514      1583                    600000                   1205000
# 207       1344      1428                    307500                   1067500
# 208       1405      1438                   1030000                   2203500
# 212       1509      1725                    200000                    760000
# 223       1367      1481                    177475                    886500
# 244       1515      1525                    173250                    490000
# 262       1495      1520                    121500                    367500
# 264       1334      1425                    162225                    392000
# ...        ...       ...                       ...                       ...
# 4762       304      1021                    182500                    340000
# 4763       386      1295                     95475                    250000
# 4765       527      1273                    121500                    222000
# 4766       537      1293                     90000                    214000
# 4769       682      1381                    130000                    227500
# 4770      1609      3081                    106500                    246950
# 4772      1366      2445                     80250                    208000
# 4773       602      1410                     67250                    245000
# 4776       783      1676                     89000                    175000
# 4782       719      1175                    320000                    875000
# 4783       762      1235                    241000                   1139500
# 4784       558       990                     79000                    590000
# 4786       892      1573                    187500                    685150
# 4787       768      1224                    250000                    710000
# 4790       864      1333                    165000                    466750
# 4797       668      1217                    120000                    314000
# 4798       829      1566                    119500                    302500
# 4802       799      1631                    137500                    267250
# 4803       542      1417                     83750                    235000
# 4805       785      1303                    180000                    335000
# 4814      1477      2493                    109498                    216000
# 4818       748      1214                     88700                    330000
# 4819       259      1017                    107000                    280000
# 4820       415      1053                    143500                    320000
# 4821       451      1134                    204900                    386250
# 4822       344      1320                    215000                    273000
# 4823       270      1073                     81500                    146500
# 4824       279      1125                    163500                    250000
# 4830       612      1352                     78000                    188000
# 4834       879      1464                    200000                    500000
#
#       All_cat_qual_2001  Level_4_qualifications_and_above_2001  ...  \
# 4                  1160                                    261  ...
# 8                  1018                                    218  ...
# 26                 1119                                    141  ...
# 29                 1120                                    127  ...
# 40                  896                                     98  ...
# 65                 1002                                     94  ...
# 88                 1002                                    118  ...
# 113                1115                                    227  ...
# 126                1112                                    238  ...
# 132                1001                                    574  ...
# 133                1040                                    295  ...
# 135                1008                                    464  ...
# 139                1056                                    258  ...
# 142                1135                                    651  ...
# 154                1117                                    330  ...
# 159                1137                                    291  ...
# 164                1158                                    378  ...
# 171                1037                                    289  ...
# 176                1216                                    659  ...
# 186                 982                                    317  ...
# 194                1080                                    467  ...
# 196                1043                                    415  ...
# 202                1078                                    575  ...
# 207                1003                                    582  ...
# 208                 907                                    431  ...
# 212                 984                                    437  ...
# 223                 944                                    263  ...
# 244                1091                                    405  ...
# 262                1090                                    357  ...
# 264                 964                                    245  ...
# ...                 ...                                    ...  ...
# 4762                191                                     25  ...
# 4763                243                                     31  ...
# 4765                364                                     78  ...
# 4766                371                                     80  ...
# 4769                502                                    129  ...
# 4770               1182                                    284  ...
# 4772                938                                    194  ...
# 4773                416                                     89  ...
# 4776                558                                    142  ...
# 4782                585                                    244  ...
# 4783                621                                    258  ...
# 4784                420                                    104  ...
# 4786                673                                    166  ...
# 4787                648                                    376  ...
# 4790                697                                    264  ...
# 4797                543                                    177  ...
# 4798                675                                    220  ...
# 4802                624                                    259  ...
# 4803                400                                    109  ...
# 4805                589                                    168  ...
# 4814               1005                                    148  ...
# 4818                581                                    266  ...
# 4819                186                                     32  ...
# 4820                330                                    134  ...
# 4821                359                                    146  ...
# 4822                247                                     43  ...
# 4823                194                                     33  ...
# 4824                201                                     35  ...
# 4830                427                                     86  ...
# 4834                682                                    313  ...
#
#       Median_income_2001  Median_income_2011  Score_2001  Score_2011  \
# 4                  26360               38200   -1.529709    0.006023
# 8                  22740               35190   -1.607967   -0.213208
# 26                 26080               35540   -1.546211   -0.316585
# 29                 25590               36230   -1.645111   -0.331296
# 40                 23990               34390   -1.787100   -0.583596
# 65                 31130               42310   -1.180167    0.264022
# 88                 23510               34850   -1.796589   -0.591428
# 113                26860               37810   -0.956993    0.626711
# 126                21850               31010   -1.702370   -0.467632
# 132                37470               59440    1.206059   14.456525
# 133                24770               32720   -1.149848    0.278280
# 135                29470               39690    0.027218    3.841467
# 139                23890               33110   -1.248563    5.591105
# 142                31500               41460    0.951966    3.737328
# 154                27630               39500   -0.848395    1.259143
# 159                24280               33790   -1.304799    0.156619
# 164                28100               39600   -0.834360    0.843612
# 171                24920               34160   -1.329576    0.570950
# 176                30680               45890    0.153313    3.719620
# 186                30260               42710   -0.221884    2.096955
# 194                32850               45740    0.212867    3.733138
# 196                34940               51120    0.593226    5.170031
# 202                38090               55210    2.674753    6.413874
# 207                38310               52340    1.274575    5.688677
# 208                49520               68560    5.090985   11.874852
# 212                33640               45590    0.163525    3.299910
# 223                29650               44630   -0.541356    3.830754
# 244                31270               46630   -0.288919    2.264171
# 262                30240               42080   -0.599314    1.284924
# 264                29510               41030   -0.701780    1.172752
# ...                  ...                 ...         ...         ...
# 4762               19750               40930   -1.488523    1.968210
# 4763               19460               36620   -1.910139    0.623531
# 4765               20380               36130   -1.500924    0.407653
# 4766               23420               38340   -1.524794    0.694540
# 4769               28590               40760   -0.996781    0.868517
# 4770               21860               35090   -1.567174    0.062014
# 4772               19610               30750   -1.865038   -0.557774
# 4773               21770               34580   -1.705080    0.040588
# 4776               22650               34780   -1.532448    0.530649
# 4782               32500               50240    0.603638    4.538194
# 4783               27800               46230    0.028999    5.324638
# 4784               23160               43470   -1.577707    2.575381
# 4786               21420               34070   -1.122451    2.156060
# 4787               34770               50620    1.036940    4.138478
# 4790               24480               33350   -0.664969    1.383582
# 4797               25080               38420   -1.092169    0.881951
# 4798               21210               39460   -1.247190    1.142829
# 4802               25370               41440   -0.700249    1.271282
# 4803               21150               33380   -1.505367   -0.206201
# 4805               22400               36060   -0.945893    0.744220
# 4814               21240               33870   -1.752373   -0.544540
# 4818               25150               41190   -0.660924    1.539995
# 4819               22010               39020   -1.694458    1.047536
# 4820               28180               40700   -0.520787    1.565105
# 4821               28920               45550   -0.189821    2.751397
# 4822               24010               38470   -1.092362    1.156505
# 4823               19150               32710   -1.941302   -0.362256
# 4824               23420               42640   -1.371718    1.567109
# 4830               22190               38020   -1.655118    0.334393
# 4834               29850               45220    0.063658    2.699337
#
#       Rank_2001  Rank_2011  Rank_chg   Z_score  score_chg  status
# 4        3841.0     2827.0    1014.0  2.250639   1.535732     ASC
# 8        4026.0     3219.0     807.0  1.791189   1.394760     ASC
# 26       3887.0     3426.0     461.0  1.023220   1.229626     ASC
# 29       4127.0     3455.0     672.0  1.491548   1.313815     ASC
# 40       4439.0     3976.0     463.0  1.027659   1.203505     ASC
# 65       2936.0     2425.0     511.0  1.134198   1.444189     ASC
# 88       4454.0     3993.0     461.0  1.023220   1.205161     ASC
# 113      2397.0     1919.0     478.0  1.060952   1.583704     ASC
# 126      4261.0     3750.0     511.0  1.134198   1.234738     ASC
# 132       257.0        1.0     256.0  0.568209  13.250466     ASC
# 133      2862.0     2400.0     462.0  1.025439   1.428128     ASC
# 135       987.0      224.0     763.0  1.693528   3.814249     ASC
# 139      3090.0       86.0    3004.0  6.667575   6.839668     ASC
# 142       379.0      244.0     135.0  0.299641   2.785362     ASC
# 154      2185.0     1300.0     885.0  1.964315   2.107539     ASC
# 159      3250.0     2576.0     674.0  1.495987   1.461417     ASC
# 164      2160.0     1692.0     468.0  1.038757   1.677972     ASC
# 171      3316.0     1978.0    1338.0  2.969779   1.900526     ASC
# 176       868.0      251.0     617.0  1.369472   3.566307     ASC
# 186      1250.0      740.0     510.0  1.131978   2.318838     ASC
# 194       823.0      247.0     576.0  1.278470   3.520271     ASC
# 196       574.0      107.0     467.0  1.036537   4.576805     ASC
# 202        27.0       59.0     -32.0 -0.071026   3.739121     ASC
# 207       232.0       83.0     149.0  0.330715   4.414103     ASC
# 208         4.0        5.0      -1.0 -0.002220   6.783867     ASC
# 212       861.0      337.0     524.0  1.163052   3.136384     ASC
# 223      1666.0      225.0    1441.0  3.198394   4.372110     ASC
# 244      1320.0      659.0     661.0  1.467133   2.553091     ASC
# 262      1767.0     1280.0     487.0  1.080928   1.884239     ASC
# 264      1929.0     1366.0     563.0  1.249615   1.874533     ASC
# ...         ...        ...       ...       ...        ...     ...
# 4762     3731.0      805.0    2926.0  6.494448   3.456733     ASC
# 4763     4641.0     1921.0    2720.0  6.037218   2.533670     ASC
# 4765     3764.0     2195.0    1569.0  3.482498   1.908577     ASC
# 4766     3825.0     1853.0    1972.0  4.376983   2.219334     ASC
# 4769     2476.0     1661.0     815.0  1.808946   1.865298     ASC
# 4770     3938.0     2731.0    1207.0  2.679015   1.629188     ASC
# 4772     4571.0     3918.0     653.0  1.449376   1.307263     ASC
# 4773     4267.0     2768.0    1499.0  3.327129   1.745668     ASC
# 4776     3846.0     2023.0    1823.0  4.046268   2.063097     ASC
# 4782      568.0      140.0     428.0  0.949974   3.934556     ASC
# 4783      986.0       98.0     888.0  1.970974   5.295639     ASC
# 4784     3960.0      540.0    3420.0  7.590914   4.153089     ASC
# 4786     2778.0      716.0    2062.0  4.576744   3.278511     ASC
# 4787      343.0      188.0     155.0  0.344033   3.101538     ASC
# 4790     1880.0     1200.0     680.0  1.509304   2.048551     ASC
# 4797     2700.0     1643.0    1057.0  2.346081   1.974119     ASC
# 4798     3084.0     1404.0    1680.0  3.728870   2.390019     ASC
# 4802     1927.0     1291.0     636.0  1.411644   1.971531     ASC
# 4803     3780.0     3211.0     569.0  1.262933   1.299166     ASC
# 4805     2372.0     1798.0     574.0  1.274031   1.690113     ASC
# 4814     4366.0     3903.0     463.0  1.027659   1.207833     ASC
# 4818     1869.0     1087.0     782.0  1.735700   2.200919     ASC
# 4819     4246.0     1485.0    2761.0  6.128220   2.741993     ASC
# 4820     1628.0     1063.0     565.0  1.254054   2.085892     ASC
# 4821     1205.0      486.0     719.0  1.595868   2.941218     ASC
# 4822     2701.0     1396.0    1305.0  2.896533   2.248866     ASC
# 4823     4673.0     3536.0    1137.0  2.523646   1.579046     ASC
# 4824     3418.0     1061.0    2357.0  5.231516   2.938827     ASC
# 4830     4158.0     2308.0    1850.0  4.106196   1.989510     ASC
# 4834      964.0      495.0     469.0  1.040976   2.635680     ASC
#
# [732 rows x 30 columns]

# %%
# checkpoint - output file
# ascending_LSOA.to_csv("ascending_LSOA.csv")

# %%
# checkpoint - uncomment next line to start from this line onwards
# ascending_LSOA.to_csv("ascending_LSOA_basic.csv")


# extract the essential details of ascending LSOAs
ascending_LSOA = ascending_LSOA.drop(ascending_LSOA.columns[1:22],axis=1)

# %% [markdown]
# ## Analysing Counts of LSOAs According to their Neighbourhoo States

# %%
# group lsoas according to their local authority

df_LA_counts = df_score.groupby(["Local_authority_name"]).size().reset_index()

# %%
# checking the number of lsoas that each local authority has respectively

df_LA_counts = pd.DataFrame(df_LA_counts)
df_LA_counts = df_LA_counts.rename(columns={0:"LSOA_count"})

# %%
df_LA_counts.head()
# Out:
#    Local_authority_name  LSOA_count
# 0  Barking and Dagenham         110
# 1                Barnet         211
# 2                Bexley         146
# 3                 Brent         173
# 4               Bromley         197

# %%
# now group lsoas by their local authority and then their neighbourhood states

df_LA_break = df_score.groupby(["Local_authority_name","status"]).size().reset_index()

# %%
# convert to dataframe and rename the data feature

df_LA_break = pd.DataFrame(df_LA_break)
df_LA_break = df_LA_break.rename(columns={0:"count"})

# %%
df_LA_break.head()
# Out:
#    Local_authority_name status  count
# 0  Barking and Dagenham    ASC      7
# 1  Barking and Dagenham    DEC      1
# 2  Barking and Dagenham    STB    102
# 3                Barnet    ASC     31
# 4                Barnet    DEC     37

# %%
# merge the 2 dataframes

df_LA_counts = df_LA_counts.merge(df_LA_break, left_on = "Local_authority_name", right_on = "Local_authority_name", how = "left")

# %%
df_LA_counts.head()
# Out:
#    Local_authority_name  LSOA_count status  count
# 0  Barking and Dagenham         110    ASC      7
# 1  Barking and Dagenham         110    DEC      1
# 2  Barking and Dagenham         110    STB    102
# 3                Barnet         211    ASC     31
# 4                Barnet         211    DEC     37

# %%
# compute the share of LSOA neighbourhood states in each local authority (in % terms)

df_LA_counts["count_share"] = df_LA_counts["count"] / df_LA_counts["LSOA_count"] * 100
df_LA_counts["count_share"] = df_LA_counts["count_share"].round(2)

# %%
df_LA_counts.head()
# Out:
#    Local_authority_name  LSOA_count status  count  count_share
# 0  Barking and Dagenham         110    ASC      7         6.36
# 1  Barking and Dagenham         110    DEC      1         0.91
# 2  Barking and Dagenham         110    STB    102        92.73
# 3                Barnet         211    ASC     31        14.69
# 4                Barnet         211    DEC     37        17.54

# %%
# extract info for only the ascending states

df_LA_counts_asc = df_LA_counts.loc[df_LA_counts["status"] == "ASC"]

# %%
# extract the 5 local authorities with the largest share of ascending lsoas

df_LA_counts_asc.nlargest(5, "count_share")
# Out:
#       Local_authority_name  LSOA_count status  count  count_share
# 55  Kensington and Chelsea         103    ASC     55        53.40
# 94             Westminster         128    ASC     46        35.94
# 70                  Newham         164    ASC     55        33.54
# 31                 Hackney         144    ASC     46        31.94
# 73               Redbridge         161    ASC     49        30.43

# %%
# extract info for only the descending states

df_LA_counts_dec = df_LA_counts.loc[df_LA_counts["status"] == "DEC"]

# %%
# extract the 5 local authorities with the largest share of descending lsoas

df_LA_counts_dec.nlargest(5, "count_share")
# Out:
#     Local_authority_name  LSOA_count status  count  count_share
# 23                Ealing         196    DEC     69        35.20
# 50              Hounslow         142    DEC     37        26.06
# 10                 Brent         173    DEC     45        26.01
# 20               Croydon         220    DEC     48        21.82
# 59  Kingston upon Thames          98    DEC     21        21.43
